# %%
doc = "The quick brown fox jumps over the lazy dog. Dogs are not lazy; they are playful and smart!"

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag
import string

# Download resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\YASH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
tokens = word_tokenize(doc)
print("Tokens:", tokens)
# Out:
# Tokens: ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.', 'Dogs', 'are', 'not', 'lazy', ';', 'they', 'are', 'playful', 'and', 'smart', '!']

# %%
pos_tags = pos_tag(tokens)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.'), ('Dogs', 'NNS'), ('are', 'VBP'), ('not', 'RB'), ('lazy', 'JJ'), (';', ':'), ('they', 'PRP'), ('are', 'VBP'), ('playful', 'JJ'), ('and', 'CC'), ('smart', 'JJ'), ('!', '.')]

# %%
stop_words = set(stopwords.words('english'))

# Remove punctuation + stopwords
filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word not in string.punctuation]
print("Filtered Tokens:", filtered_tokens)
# Out:
# Filtered Tokens: ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'Dogs', 'lazy', 'playful', 'smart']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['quick', 'brown', 'fox', 'jump', 'lazi', 'dog', 'dog', 'lazi', 'play', 'smart']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'Dogs', 'lazy', 'playful', 'smart']

# %%
from collections import Counter

tf = Counter(filtered_tokens)
print("Term Frequency:", tf)
# Out:
# Term Frequency: Counter({'lazy': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'dog': 1, 'Dogs': 1, 'playful': 1, 'smart': 1})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create list of documents
docs = ["The quick brown fox jumps over the lazy dog.", 
        "Dogs are not lazy; they are playful and smart!"]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(docs)

# Print TF-IDF matrix
print("TF-IDF Matrix:")
print(X.toarray())

# Print feature names
print("Feature Names:", vectorizer.get_feature_names_out())
# Out:
# TF-IDF Matrix:
# [[0.         0.         0.30851498 0.30851498 0.         0.30851498
#   0.30851498 0.21951095 0.         0.30851498 0.         0.30851498
#   0.         0.61702996 0.        ]
#  [0.30851498 0.61702996 0.         0.         0.30851498 0.
#   0.         0.21951095 0.30851498 0.         0.30851498 0.
#   0.30851498 0.         0.30851498]]
# Feature Names: ['and' 'are' 'brown' 'dog' 'dogs' 'fox' 'jumps' 'lazy' 'not' 'over'
#  'playful' 'quick' 'smart' 'the' 'they']
